# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("data-export (1).csv")

# %%
df.head()
# Out:
#           # ----------------------------------------  \
# 0  Session primary channel group (Default channel...
# 1                                             Direct
# 2                                     Organic Social
# 3                                             Direct
# 4                                     Organic Social
#
#                  Unnamed: 1 Unnamed: 2 Unnamed: 3        Unnamed: 4  \
# 0  Date + hour (YYYYMMDDHH)      Users   Sessions  Engaged sessions
# 1                2024041623        237        300               144
# 2                2024041719        208        267               132
# 3                2024041723        188        233               115
# 4                2024041718        187        256               125
#
#                             Unnamed: 5                 Unnamed: 6  \
# 0  Average engagement time per session  Engaged sessions per user
# 1                   47.526666666666700         0.6075949367088610
# 2                    32.09737827715360         0.6346153846153850
# 3                    39.93991416309010         0.6117021276595740
# 4                          32.16015625         0.6684491978609630
#
#            Unnamed: 7           Unnamed: 8   Unnamed: 9
# 0  Events per session      Engagement rate  Event count
# 1   4.673333333333330                 0.48         1402
# 2   4.295880149812730   0.4943820224719100         1147
# 3   4.587982832618030  0.49356223175965700         1069
# 4            4.078125           0.48828125         1044

# %%
df.columns = df.iloc[0]
df.head()
# Out:
# 0 Session primary channel group (Default channel group)  \
# 0  Session primary channel group (Default channel...
# 1                                             Direct
# 2                                     Organic Social
# 3                                             Direct
# 4                                     Organic Social
#
# 0  Date + hour (YYYYMMDDHH)  Users  Sessions  Engaged sessions  \
# 0  Date + hour (YYYYMMDDHH)  Users  Sessions  Engaged sessions
# 1                2024041623    237       300               144
# 2                2024041719    208       267               132
# 3                2024041723    188       233               115
# 4                2024041718    187       256               125
#
# 0  Average engagement time per session  Engaged sessions per user  \
# 0  Average engagement time per session  Engaged sessions per user
# 1                   47.526666666666700         0.6075949367088610
# 2                    32.09737827715360         0.6346153846153850
# 3                    39.93991416309010         0.6117021276595740
# 4                          32.16015625         0.6684491978609630
#
# 0  Events per session      Engagement rate  Event count
# 0  Events per session      Engagement rate  Event count
# 1   4.673333333333330                 0.48         1402
# 2   4.295880149812730   0.4943820224719100         1147
# 3   4.587982832618030  0.49356223175965700         1069
# 4            4.078125           0.48828125         1044

# %%
df.columns  = df.iloc[0]

# %%
df.head()
# Out:
# 0 Session primary channel group (Default channel group)  \
# 0  Session primary channel group (Default channel...
# 1                                             Direct
# 2                                     Organic Social
# 3                                             Direct
# 4                                     Organic Social
#
# 0  Date + hour (YYYYMMDDHH)  Users  Sessions  Engaged sessions  \
# 0  Date + hour (YYYYMMDDHH)  Users  Sessions  Engaged sessions
# 1                2024041623    237       300               144
# 2                2024041719    208       267               132
# 3                2024041723    188       233               115
# 4                2024041718    187       256               125
#
# 0  Average engagement time per session  Engaged sessions per user  \
# 0  Average engagement time per session  Engaged sessions per user
# 1                   47.526666666666700         0.6075949367088610
# 2                    32.09737827715360         0.6346153846153850
# 3                    39.93991416309010         0.6117021276595740
# 4                          32.16015625         0.6684491978609630
#
# 0  Events per session      Engagement rate  Event count
# 0  Events per session      Engagement rate  Event count
# 1   4.673333333333330                 0.48         1402
# 2   4.295880149812730   0.4943820224719100         1147
# 3   4.587982832618030  0.49356223175965700         1069
# 4            4.078125           0.48828125         1044

# %%
df= df.drop(index = 0).reset_index(drop = True)
# Out:
# 0    Session primary channel group (Default channel group)  \
# 0                                                Direct
# 1                                        Organic Social
# 2                                                Direct
# 3                                        Organic Social
# 4                                        Organic Social
# ...                                                 ...
# 3177                                         Unassigned
# 3178                                         Unassigned
# 3179                                         Unassigned
# 3180                                         Unassigned
# 3181                                         Unassigned
#
# 0    Date + hour (YYYYMMDDHH) Users Sessions Engaged sessions  \
# 0                  2024041623   237      300              144
# 1                  2024041719   208      267              132
# 2                  2024041723   188      233              115
# 3                  2024041718   187      256              125
# 4                  2024041720   175      221              112
# ...                       ...   ...      ...              ...
# 3177               2024042806     0        1                0
# 3178               2024043005     0        1                0
# 3179               2024043006     0        1                0
# 3180               2024050105     0        1                0
# 3181               2024050307     0        1                0
#
# 0    Average engagement time per session Engaged sessions per user  \
# 0                     47.526666666666700        0.6075949367088610
# 1                      32.09737827715360        0.6346153846153850
# 2                      39.93991416309010        0.6117021276595740
# 3                            32.16015625        0.6684491978609630
# 4                     46.918552036199100                      0.64
# ...                                  ...                       ...
# 3177                                   0                         0
# 3178                                   0                         0
# 3179                                   0                         0
# 3180                                   0                         0
# 3181                                   0                         0
#
# 0    Events per session      Engagement rate Event count
# 0     4.673333333333330                 0.48        1402
# 1     4.295880149812730   0.4943820224719100        1147
# 2     4.587982832618030  0.49356223175965700        1069
# 3              4.078125           0.48828125        1044
# 4     4.529411764705880   0.5067873303167420        1001
# ...                 ...                  ...         ...
# 3177                  2                    0           2
# 3178                  2                    0           2
# 3179                  2                    0           2
# 3180                  2                    0           2
# 3181                  2                    0           2
#
# [3182 rows x 10 columns]

# %%
df.columns = ["channel group", "Datehour", "Users", "Sessions", "Engaged Sessions", "Average Engagement", "Engaged Sessions Per User", "Events Per Session", "Engagement Rate", "Event Count"]

# %%
df.head()
# Out:
#                                        channel group  \
# 0  Session primary channel group (Default channel...
# 1                                             Direct
# 2                                     Organic Social
# 3                                             Direct
# 4                                     Organic Social
#
#                    Datehour  Users  Sessions  Engaged Sessions  \
# 0  Date + hour (YYYYMMDDHH)  Users  Sessions  Engaged sessions
# 1                2024041623    237       300               144
# 2                2024041719    208       267               132
# 3                2024041723    188       233               115
# 4                2024041718    187       256               125
#
#                     Average Engagement  Engaged Sessions Per User  \
# 0  Average engagement time per session  Engaged sessions per user
# 1                   47.526666666666700         0.6075949367088610
# 2                    32.09737827715360         0.6346153846153850
# 3                    39.93991416309010         0.6117021276595740
# 4                          32.16015625         0.6684491978609630
#
#    Events Per Session      Engagement Rate  Event Count
# 0  Events per session      Engagement rate  Event count
# 1   4.673333333333330                 0.48         1402
# 2   4.295880149812730   0.4943820224719100         1147
# 3   4.587982832618030  0.49356223175965700         1069
# 4            4.078125           0.48828125         1044

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3183 entries, 0 to 3182
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   channel group              3183 non-null   object
#  1   Datehour                   3183 non-null   object
#  2   Users                      3183 non-null   object
#  3   Sessions                   3183 non-null   object
#  4   Engaged Sessions           3183 non-null   object
#  5   Average Engagement         3183 non-null   object
#  6   Engaged Sessions Per User  3183 non-null   object
#  7   Events Per Session         3183 non-null   object
#  8   Engagement Rate            3183 non-null   object
#  9   Event Count                3183 non-null   object
# dtypes: object(10)
# memory usage: 248.8+ KB

# %%
df.head()
# Out:
#                                        channel group  \
# 0  Session primary channel group (Default channel...
# 1                                             Direct
# 2                                     Organic Social
# 3                                             Direct
# 4                                     Organic Social
#
#                    Datehour  Users  Sessions  Engaged Sessions  \
# 0  Date + hour (YYYYMMDDHH)  Users  Sessions  Engaged sessions
# 1                2024041623    237       300               144
# 2                2024041719    208       267               132
# 3                2024041723    188       233               115
# 4                2024041718    187       256               125
#
#                     Average Engagement  Engaged Sessions Per User  \
# 0  Average engagement time per session  Engaged sessions per user
# 1                   47.526666666666700         0.6075949367088610
# 2                    32.09737827715360         0.6346153846153850
# 3                    39.93991416309010         0.6117021276595740
# 4                          32.16015625         0.6684491978609630
#
#    Events Per Session      Engagement Rate  Event Count
# 0  Events per session      Engagement rate  Event count
# 1   4.673333333333330                 0.48         1402
# 2   4.295880149812730   0.4943820224719100         1147
# 3   4.587982832618030  0.49356223175965700         1069
# 4            4.078125           0.48828125         1044

# %%
df["Datehour"] = pd.to_datetime(df["Datehour"], format="%Y%m%d%H", errors="coerce")
df.head()
# Out:
#                                        channel group            Datehour  \
# 0  Session primary channel group (Default channel...                 NaT
# 1                                             Direct 2024-04-16 23:00:00
# 2                                     Organic Social 2024-04-17 19:00:00
# 3                                             Direct 2024-04-17 23:00:00
# 4                                     Organic Social 2024-04-17 18:00:00
#
#    Users  Sessions  Engaged Sessions                   Average Engagement  \
# 0  Users  Sessions  Engaged sessions  Average engagement time per session
# 1    237       300               144                   47.526666666666700
# 2    208       267               132                    32.09737827715360
# 3    188       233               115                    39.93991416309010
# 4    187       256               125                          32.16015625
#
#    Engaged Sessions Per User  Events Per Session      Engagement Rate  \
# 0  Engaged sessions per user  Events per session      Engagement rate
# 1         0.6075949367088610   4.673333333333330                 0.48
# 2         0.6346153846153850   4.295880149812730   0.4943820224719100
# 3         0.6117021276595740   4.587982832618030  0.49356223175965700
# 4         0.6684491978609630            4.078125           0.48828125
#
#    Event Count
# 0  Event count
# 1         1402
# 2         1147
# 3         1069
# 4         1044

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3183 entries, 0 to 3182
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   channel group              3183 non-null   object
#  1   Datehour                   3182 non-null   datetime64[ns]
#  2   Users                      3183 non-null   object
#  3   Sessions                   3183 non-null   object
#  4   Engaged Sessions           3183 non-null   object
#  5   Average Engagement         3183 non-null   object
#  6   Engaged Sessions Per User  3183 non-null   object
#  7   Events Per Session         3183 non-null   object
#  8   Engagement Rate            3183 non-null   object
#  9   Event Count                3183 non-null   object
# dtypes: datetime64[ns](1), object(9)
# memory usage: 248.8+ KB

# %%
numeric_cols = df.columns.drop(["channel group","Datehour"])
df[numeric_cols] = df[numeric_cols].apply(pd.to_numeric, errors = "coerce")
df["Hour"] = df["Datehour"].dt.hour

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3183 entries, 0 to 3182
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   channel group              3183 non-null   object
#  1   Datehour                   3182 non-null   datetime64[ns]
#  2   Users                      3182 non-null   float64
#  3   Sessions                   3182 non-null   float64
#  4   Engaged Sessions           3182 non-null   float64
#  5   Average Engagement         3182 non-null   float64
#  6   Engaged Sessions Per User  3182 non-null   float64
#  7   Events Per Session         3182 non-null   float64
#  8   Engagement Rate            3182 non-null   float64
#  9   Event Count                3182 non-null   float64
#  10  Hour                       3182 non-null   float64
# dtypes: datetime64[ns](1), float64(9), object(1)
# memory usage: 273.7+ KB

# %%
df.head()
# Out:
#                                        channel group            Datehour  \
# 0  Session primary channel group (Default channel...                 NaT
# 1                                             Direct 2024-04-16 23:00:00
# 2                                     Organic Social 2024-04-17 19:00:00
# 3                                             Direct 2024-04-17 23:00:00
# 4                                     Organic Social 2024-04-17 18:00:00
#
#    Users  Sessions  Engaged Sessions  Average Engagement  \
# 0    NaN       NaN               NaN                 NaN
# 1  237.0     300.0             144.0           47.526667
# 2  208.0     267.0             132.0           32.097378
# 3  188.0     233.0             115.0           39.939914
# 4  187.0     256.0             125.0           32.160156
#
#    Engaged Sessions Per User  Events Per Session  Engagement Rate  \
# 0                        NaN                 NaN              NaN
# 1                   0.607595            4.673333         0.480000
# 2                   0.634615            4.295880         0.494382
# 3                   0.611702            4.587983         0.493562
# 4                   0.668449            4.078125         0.488281
#
#    Event Count  Hour
# 0          NaN   NaN
# 1       1402.0  23.0
# 2       1147.0  19.0
# 3       1069.0  23.0
# 4       1044.0  18.0

# %%
df= df.drop(index = 0).reset_index(drop = True)

# %%
df.head()
# Out:
#     channel group            Datehour  Users  Sessions  Engaged Sessions  \
# 0          Direct 2024-04-16 23:00:00  237.0     300.0             144.0
# 1  Organic Social 2024-04-17 19:00:00  208.0     267.0             132.0
# 2          Direct 2024-04-17 23:00:00  188.0     233.0             115.0
# 3  Organic Social 2024-04-17 18:00:00  187.0     256.0             125.0
# 4  Organic Social 2024-04-17 20:00:00  175.0     221.0             112.0
#
#    Average Engagement  Engaged Sessions Per User  Events Per Session  \
# 0           47.526667                   0.607595            4.673333
# 1           32.097378                   0.634615            4.295880
# 2           39.939914                   0.611702            4.587983
# 3           32.160156                   0.668449            4.078125
# 4           46.918552                   0.640000            4.529412
#
#    Engagement Rate  Event Count  Hour
# 0         0.480000       1402.0  23.0
# 1         0.494382       1147.0  19.0
# 2         0.493562       1069.0  23.0
# 3         0.488281       1044.0  18.0
# 4         0.506787       1001.0  20.0

# %%
df.describe()
# Out:
#                             Datehour        Users     Sessions  \
# count                           3182  3182.000000  3182.000000
# mean   2024-04-20 01:17:07.278441216    41.935889    51.192646
# min              2024-04-06 00:00:00     0.000000     1.000000
# 25%              2024-04-13 02:15:00    20.000000    24.000000
# 50%              2024-04-20 02:00:00    42.000000    51.000000
# 75%              2024-04-26 22:00:00    60.000000    71.000000
# max              2024-05-03 23:00:00   237.000000   300.000000
# std                              NaN    29.582258    36.919962
#
#        Engaged Sessions  Average Engagement  Engaged Sessions Per User  \
# count       3182.000000         3182.000000                3182.000000
# mean          28.325581           66.644581                   0.606450
# min            0.000000            0.000000                   0.000000
# 25%           13.000000           32.103034                   0.561404
# 50%           27.000000           49.020202                   0.666667
# 75%           41.000000           71.487069                   0.750000
# max          144.000000         4525.000000                   2.000000
# std           20.650569          127.200659                   0.264023
#
#        Events Per Session  Engagement Rate  Event Count         Hour
# count         3182.000000      3182.000000  3182.000000  3182.000000
# mean             4.675969         0.503396   242.272470    11.807040
# min              1.000000         0.000000     1.000000     0.000000
# 25%              3.750000         0.442902   103.000000     6.000000
# 50%              4.410256         0.545455   226.000000    12.000000
# 75%              5.217690         0.633333   339.000000    18.000000
# max             56.000000         1.000000  1402.000000    23.000000
# std              2.795228         0.228206   184.440313     6.886686

# %% [markdown]
# # Session and User Over Time

# %%
sns.set(style="whitegrid")

# %%
plt.figure(figsize=(10,5))
df.groupby("Datehour")[["Sessions","Users"]].sum().plot(ax=plt.gca())
plt.title("Session and User Over Time")
plt.xlabel("Datehour")
plt.ylabel("count")
plt.show()

# %% [markdown]
# # Total users by chaneel

# %%
plt.figure(figsize=(8,5))
sns.barplot(data=df, x="channel group", y="Users", estimator=np.sum, palette="viridis")
plt.title("Total user by chanel")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\nandk\AppData\Local\Temp\ipykernel_11000\2044382427.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x="channel group", y="Users", estimator=np.sum, palette="viridis")

# %% [markdown]
# # Average engagement time by chanel

# %%
plt.figure(figsize=(8,5))
sns.barplot(data=df, x="channel group", y="Average Engagement", estimator=np.mean, palette="magma")
plt.title("Average Engagement Time by chanel")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\nandk\AppData\Local\Temp\ipykernel_11000\576994954.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x="channel group", y="Average Engagement", estimator=np.mean, palette="magma")

# %% [markdown]
# # Engagement Rate Distribution by channel

# %%
plt.figure(figsize=(8,5))
sns.boxplot(data=df, x="channel group", y="Engagement Rate", palette="coolwarm")
plt.title("Engagement Rate Distribution by channel")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\nandk\AppData\Local\Temp\ipykernel_11000\1728123187.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x="channel group", y="Engagement Rate", palette="coolwarm")

# %% [markdown]
# # Engaged Vs Non-Engaged session

# %%
df.head()
# Out:
#     channel group            Datehour  Users  Sessions  Engaged Sessions  \
# 0          Direct 2024-04-16 23:00:00  237.0     300.0             144.0
# 1  Organic Social 2024-04-17 19:00:00  208.0     267.0             132.0
# 2          Direct 2024-04-17 23:00:00  188.0     233.0             115.0
# 3  Organic Social 2024-04-17 18:00:00  187.0     256.0             125.0
# 4  Organic Social 2024-04-17 20:00:00  175.0     221.0             112.0
#
#    Average Engagement  Engaged Sessions Per User  Events Per Session  \
# 0           47.526667                   0.607595            4.673333
# 1           32.097378                   0.634615            4.295880
# 2           39.939914                   0.611702            4.587983
# 3           32.160156                   0.668449            4.078125
# 4           46.918552                   0.640000            4.529412
#
#    Engagement Rate  Event Count  Hour
# 0         0.480000       1402.0  23.0
# 1         0.494382       1147.0  19.0
# 2         0.493562       1069.0  23.0
# 3         0.488281       1044.0  18.0
# 4         0.506787       1001.0  20.0

# %%
session_df = df.groupby("channel group")[["Sessions","Engaged Sessions"]].sum().reset_index()
session_df["Non-Engaged"] = session_df["Sessions"] - session_df["Engaged Sessions"]
session_df_melted = session_df.melt(id_vars="channel group", value_vars=["Engaged Sessions", "Non-Engaged"])

plt.figure(figsize=(8,5))
sns.barplot(data=session_df_melted, x="channel group", y="value", hue="variable")
plt.title("Engaged Vs Non-Engaged session")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Traffic by Hour and Channel

# %%
heatmap_data = df.groupby(["Hour","channel group"])["Sessions"].sum().unstack().fillna(0)

plt.figure(figsize=(12,6))
sns.heatmap(heatmap_data, cmap="YlGnBu", linewidths=.5, annot=True, fmt=".0f")
plt.title("Traffic by Hour and Channel")
plt.xlabel("Channel Group")
plt.ylabel("Hour of Day")
plt.show()

# %% [markdown]
# # Engagement Rate Vs Sessions Over Time

# %%
df.head()
# Out:
#     channel group            Datehour  Users  Sessions  Engaged Sessions  \
# 0          Direct 2024-04-16 23:00:00  237.0     300.0             144.0
# 1  Organic Social 2024-04-17 19:00:00  208.0     267.0             132.0
# 2          Direct 2024-04-17 23:00:00  188.0     233.0             115.0
# 3  Organic Social 2024-04-17 18:00:00  187.0     256.0             125.0
# 4  Organic Social 2024-04-17 20:00:00  175.0     221.0             112.0
#
#    Average Engagement  Engaged Sessions Per User  Events Per Session  \
# 0           47.526667                   0.607595            4.673333
# 1           32.097378                   0.634615            4.295880
# 2           39.939914                   0.611702            4.587983
# 3           32.160156                   0.668449            4.078125
# 4           46.918552                   0.640000            4.529412
#
#    Engagement Rate  Event Count  Hour
# 0         0.480000       1402.0  23.0
# 1         0.494382       1147.0  19.0
# 2         0.493562       1069.0  23.0
# 3         0.488281       1044.0  18.0
# 4         0.506787       1001.0  20.0

# %%
df_plot = df.groupby("Datehour")[["Engagement Rate","Sessions"]].mean().reset_index()

plt.figure(figsize=(10,5))
plt.plot(df_plot["Datehour"], df_plot["Engagement Rate"], label="Engagement Rate", color="green")
plt.plot(df_plot["Datehour"], df_plot["Sessions"], label="Sessions", color="blue")
plt.title("Engagement Rate Vs Sessions Over Time")
plt.legend()
plt.grid(True)
plt.show()
